# %% [markdown]
# # Simple Random Sampling

# %%
import pandas as pd

# %%
df_2015 = pd.read_csv("marathon_results_2015.csv")
df_2016 = pd.read_csv("marathon_results_2016.csv")
df_2017 = pd.read_csv("marathon_results_2017.csv")

# %%
df = pd.concat([df_2015,df_2016,df_2017])

# %%
#get total number of rows in original data
original_row_count = len(df)
original_row_count
# Out:
# 79638

# %%
#Perform simple random sampling (selecting  1/10th of the records )
sample_df = df.sample(frac=0.1,random_state=42)

# %%
#Get the total number of rows in sampled dataframe
sample_row_count = len(sample_df)
sample_row_count
# Out:
# 5331

# %%
sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)

# %%
df.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
sample_df.head()
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F            City State  \
# 24038     24038.0  31350    Labonte, Laura R.   34   F     Charlestown    MA
# 20218     20218.0  21352        Vargas, Mario   64   M  Shaker Heights    OH
# 23755     23755.0  27235  Wilkins, Stephen D.   53   M      Dorchester    MA
# 1447       1447.0   4337     Johnson, David T   32   M         Brandon    FL
# 25121         NaN  26089       Bashor, Mari W   67   F      Sacramento    CA
#
#       Country Citizen Unnamed: 9  ...     Pace Proj Time Official Time  \
# 24038     USA     NaN        NaN  ...  0:10:49         -       4:43:30
# 20218     USA     NaN        NaN  ...  0:09:28         -       4:08:04
# 23755     USA     NaN        NaN  ...  0:10:40         -       4:39:30
# 1447      USA     NaN        NaN  ...  0:06:39         -       2:54:17
# 25121     USA     NaN        NaN  ...  0:11:58   5:13:34       5:13:34
#
#       Overall Gender Division Unnamed: 8 hour mins seconds
# ...

# %%
sample_df['hour'] = pd.to_numeric(sample_df['hour'])
sample_df['mins'] = pd.to_numeric(sample_df['mins'])
sample_df['seconds'] = pd.to_numeric(sample_df['seconds'])

# %%
sample_df['Total_time'] = sample_df['hour']*3600 + sample_df['mins']*60 + sample_df['seconds']
sample_df
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F              City  \
# 24038     24038.0  31350    Labonte, Laura R.   34   F       Charlestown
# 20218     20218.0  21352        Vargas, Mario   64   M    Shaker Heights
# 23755     23755.0  27235  Wilkins, Stephen D.   53   M        Dorchester
# 1447       1447.0   4337     Johnson, David T   32   M           Brandon
# 25121         NaN  26089       Bashor, Mari W   67   F        Sacramento
# ...           ...    ...                  ...  ...  ..               ...
# 23322     23322.0  11427        Silwal, Suman   45   M            Pelham
# 5102          NaN  10536         Baganz, Paul   62   M       Fond Du Lac
# 12821     12821.0  12730       Strutz, Nicole   22   F        Two Rivers
# 13241         NaN  21185    Greengrass, Suzie   45   F              Cary
# 8893       8893.0  13873  Fitzgerald, Vanessa   38   F  Long Island City
#
#       State Country Citizen Unnamed: 9  ... Proj Time Official Time Overall  \
# ...

# %%
simple_random_mean = sample_df['Total_time'].mean()
simple_random_mean
# Out:
# 13955.71320944249

# %%
print(f"number of rows in original dataframe:{original_row_count}")
print(f"number of rows in sample dataframe:{sample_row_count}")
# Out:
# number of rows in original dataframe:79638
# number of rows in sample dataframe:7964

# %% [markdown]
# # Systematic Random Sampling

# %%
# Perform Systematic sampling (Picking every 7th record)
#::7 means from start to end , pick every 7th record
#,: means pick from all columns

sample_row_count= df.iloc[::7, :]

# %%
#GEt total number of rows from sample dataframe
sample_row_count = len(sample_row_count)
sample_row_count
# Out:
# 11377

# %%
#Print the first few rows of original and samples dataframes
print("First  rows of original dataframe: ")
df.head()
# Out:
# First new rows of original dataframe:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
# ...

# %%
sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)

sample_df['hour'] = pd.to_numeric(sample_df['hour'])
sample_df['mins'] = pd.to_numeric(sample_df['mins'])
sample_df['seconds'] = pd.to_numeric(sample_df['seconds'])

sample_df['Total_time'] = sample_df['hour']*3600 + sample_df['mins']*60 + sample_df['seconds']

print('sample_df')

simple_random_mean = sample_df['Total_time'].mean()
simple_random_mean
# Out:
# sample_df
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_18364\1757059156.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_18364\1757059156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df['hour'] = pd.to_numeric(sample_df['hour'])
# ...

# %%
print("First few rows of sampled dataframe")
sample_df.head()
# Out:
# First few rows of sampled dataframe
#     Unnamed: 0 Bib                   Name  Age M/F               City State  \
# 0          0.0   3         Desisa, Lelisa   25   M               Ambo   NaN
# 1          1.0   4  Tsegay, Yemane Adhane   30   M        Addis Ababa   NaN
# 8          8.0   5           Tola, Tadese   27   M        Addis Ababa   NaN
# 12        12.0  15         April, Lusapho   32   M          Uitenhage   NaN
# 14        14.0  76          Goffi, Danilo   42   M  Parabiago - Milan   NaN
#
#    Country Citizen Unnamed: 9  ... Proj Time Official Time Overall Gender  \
# 0      ETH     NaN        NaN  ...         -       2:09:17       1      1
# 1      ETH     NaN        NaN  ...         -       2:09:48       2      2
# 8      ETH     NaN        NaN  ...         -       2:13:35       9      9
# 12     RSA     NaN        NaN  ...         -       2:16:25      13     13
# 14     ITA     NaN        NaN  ...         -       2:18:44      15     15
#
# ...

# %%
#Print number of rows in original and sampled datafrmae
print(f"\nNumber of rows in original dataframe: {original_row_count}")
print(f"\nNumber of rows in sampled dataframe: {sample_row_count}")
# Out:
# Number of rows in original dataframe: 79638
#
# Number of rows in sampled dataframe: 7964

# %% [markdown]
# # Stratified Random Sampling

# %%
#Find the total number of males and females athelete
total_males = len(df[df['M/F'] == 'M'])
total_females = len(df[df['M/F'] == 'F'])

# %%
total_males
# Out:
# 43482

# %%
total_females
# Out:
# 36156

# %%
#Calculate the proportionate number of males and female athelete for a sample
sample_size = int(0.1*original_row_count)
print(sample_size)
sample_males = int(0.1* total_males)
print(sample_males)
sample_females = int(0.1*total_females)
print(sample_females)
# Out:
# 7963
# 4348
# 3615

# %%
## Generate proportationate samples of male and female
male_Samples = df[df['M/F'] == 'M'].sample(n=sample_males,random_state=42)
male_Samples
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F           City State  \
# 17164     17164.0   5919    Pucci, Ferdinando   36   M         Quincy    MA
# 23023         NaN  28464      Burns, Shawn M.   44   M       Pembroke    MA
# 2331          NaN   2338        Sauvola, Lars   41   M         Rindge    NH
# 6577       6577.0   9603   Burns, Jonathan M.   47   M  Mechanicsburg    PA
# 17054     17054.0   5434       Benjamin, Elad   40   M        Raanana   NaN
# ...           ...    ...                  ...  ...  ..            ...   ...
# 5319          NaN   1604         Cutts, Kevin   39   M      Fort Mill    SC
# 4111          NaN   6254    Poole, Richard J.   39   M   Williamsport    PA
# 4995       4995.0   4007  Presutti, Francesco   53   M       New York    NY
# 22770     22770.0  27902        Sibley, Bruce   53   M       New York    NY
# 17317     17317.0  18915     Yoshida, Junichi   57   M   Little Ferry    NJ
#
# ...

# %%
female_samples = df[df['M/F'] == 'F'].sample(n= sample_females,random_state=42)
female_samples
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F         City State  \
# 16892         NaN  15213       Levens, Sara M   21   F     Monument    CO
# 13746         NaN  31089   Donovan, Christine   24   F       Boston    MA
# 13532         NaN  22036   McKinnis, Karen R.   53   F   Fair Grove    MO
# 18011         NaN  24656       Bagshaw, Helen   51   F      Toronto    ON
# 19004     19004.0  25323       Luna, Maria G.   61   F       Bogota   NaN
# ...           ...    ...                  ...  ...  ..          ...   ...
# 15618         NaN   5561        Mutter, Katie   26   F     Syracuse    NY
# 23455     23455.0  25833     Stephens, Eve M.   40   F       Austin    TX
# 17957         NaN  18266  Jarboe, Jennifer M.   24   F   Washington    DC
# 21966     21966.0  24163     Leland, Pamela A   55   F       Dorado    PR
# 11362     11362.0  16540     Willard, Ellen M   34   F  San Antonio    TX
#
#       Country Citizen Unnamed: 9  ...      30K      35K      40K     Pace  \
# ...

# %%
##Combining the male and female samples into a single dataframe
sample_df = pd.concat([male_Samples,female_samples])
sample_row_count = len(sample_df)

# %%
sample_df
# Out:
#        Unnamed: 0    Bib                 Name  Age M/F           City State  \
# 17164     17164.0   5919    Pucci, Ferdinando   36   M         Quincy    MA
# 23023         NaN  28464      Burns, Shawn M.   44   M       Pembroke    MA
# 2331          NaN   2338        Sauvola, Lars   41   M         Rindge    NH
# 6577       6577.0   9603   Burns, Jonathan M.   47   M  Mechanicsburg    PA
# 17054     17054.0   5434       Benjamin, Elad   40   M        Raanana   NaN
# ...           ...    ...                  ...  ...  ..            ...   ...
# 15618         NaN   5561        Mutter, Katie   26   F       Syracuse    NY
# 23455     23455.0  25833     Stephens, Eve M.   40   F         Austin    TX
# 17957         NaN  18266  Jarboe, Jennifer M.   24   F     Washington    DC
# 21966     21966.0  24163     Leland, Pamela A   55   F         Dorado    PR
# 11362     11362.0  16540     Willard, Ellen M   34   F    San Antonio    TX
#
# ...

# %%
sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)

sample_df['hour'] = pd.to_numeric(sample_df['hour'])
sample_df['mins'] = pd.to_numeric(sample_df['mins'])
sample_df['seconds'] = pd.to_numeric(sample_df['seconds'])

sample_df['Total_time'] = sample_df['hour']*3600 + sample_df['mins']*60 + sample_df['seconds']

print('sample_df')

simple_random_mean = sample_df['Total_time'].mean()
simple_random_mean
# Out:
# sample_df
# 14009.489137259827

# %%
##print the first few rows of original and sampled dataframe
df.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
#   Official Time Overall Gender Division Unnamed: 8
# ...

# %%
sample_df.head()
# Out:
#        Unnamed: 0    Bib                Name  Age M/F           City State  \
# 17164     17164.0   5919   Pucci, Ferdinando   36   M         Quincy    MA
# 23023         NaN  28464     Burns, Shawn M.   44   M       Pembroke    MA
# 2331          NaN   2338       Sauvola, Lars   41   M         Rindge    NH
# 6577       6577.0   9603  Burns, Jonathan M.   47   M  Mechanicsburg    PA
# 17054     17054.0   5434      Benjamin, Elad   40   M        Raanana   NaN
#
#       Country Citizen Unnamed: 9  ... Proj Time Official Time Overall Gender  \
# 17164     USA     NaN        NaN  ...         -       4:07:27   17166  10390
# 23023     USA     NaN        NaN  ...   4:41:59       4:41:59   23023  12863
# 2331      USA     NaN        NaN  ...   3:06:43       3:06:43    2332   2154
# 6577      USA     NaN        NaN  ...         -       3:18:23    6578   5654
# 17054     ISR     NaN        NaN  ...         -       3:52:28   17055  10576
#
# ...

# %%
#Print number of rows in original and sampled datafrmae
print(f"\nNumber of rows in original dataframe: {original_row_count}")
print(f"\nNumber of rows in sampled dataframe: {sample_row_count}")
# Out:
# Number of rows in original dataframe: 79638
#
# Number of rows in sampled dataframe: 7963

# %% [markdown]
# # Cluster Sampling

# %%
#Find unique contries the athletes are from
unique_countries = df['Country'].unique()
num_countries= len(unique_countries)
num_countries
# Out:
# 105

# %%
#Randomly select half of countries
import numpy as np
np.random.seed(42)

# %%
selected_countries = np.random.choice(unique_countries, size=num_countries//2, replace=False)
selected_countries
# Out:
# array(['COL', 'JAM', 'EST', 'IND', 'PAN', 'SMR', 'NGR', 'LUX', 'NZL',
#        'ETH', 'SWE', 'SUI', 'BDI', 'ALG', 'UGA', 'RSA', 'TWN', 'AUT',
#        'AUS', 'CHI', 'GRN', 'ARG', 'DEN', 'PHI', 'SIN', 'BAH', 'ECU',
#        'TPE', 'KOR', 'BEL', 'ALB', 'BLR', 'MGL', 'QAT', 'FIN', 'ZIM',
#        'ITA', 'URU', 'ESA', 'NOR', 'FRA', 'GER', 'UAE', 'NED', 'JPN',
#        'PER', 'TUR', 'LAT', 'GUA', 'BRA', 'JOR', 'ISL'], dtype=object)

# %%
#Create a new dataframe containing all records of selcted countries
sample_df = df[df['Country'].isin(selected_countries)]

# %%
#Get total number of rows in sample dataframe
sample_row_count= len(sample_df)
sample_row_count
# Out:
# 5331

# %%
sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)

sample_df['hour'] = pd.to_numeric(sample_df['hour'])
sample_df['mins'] = pd.to_numeric(sample_df['mins'])
sample_df['seconds'] = pd.to_numeric(sample_df['seconds'])

sample_df['Total_time'] = sample_df['hour']*3600 + sample_df['mins']*60 + sample_df['seconds']

print('sample_df')

sample_random_mean = sample_df['Total_time'].mean()
sample_random_mean
# Out:
# sample_df
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_18364\3376225632.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_18364\3376225632.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df[['hour','mins','seconds']] = sample_df['Official Time'].str.split(':', expand = True)
# ...

# %%
##print the first few rows of original and sampled dataframe
print("First few rows of original dataframe: ")
df.head()
# Out:
# First few rows of original dataframe:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:32:00  1:47:59  2:02:39  0:04:56         -
# 1     NaN        NaN  ...  1:31:59  1:47:59  2:02:42  0:04:58         -
# 2     NaN        NaN  ...  1:32:00  1:47:59  2:03:01  0:04:59         -
# 3     NaN        NaN  ...  1:32:00  1:48:03  2:03:47  0:05:00         -
# 4     NaN        NaN  ...  1:32:00  1:47:59  2:03:27  0:05:00         -
#
# ...

# %%
##print the first few rows of original and sampled dataframe
print("First few rows of sample dataframe: ")
sample_df.head()
# Out:
# First few rows of sample dataframe:
#     Unnamed: 0 Bib                   Name  Age M/F               City State  \
# 0          0.0   3         Desisa, Lelisa   25   M               Ambo   NaN
# 1          1.0   4  Tsegay, Yemane Adhane   30   M        Addis Ababa   NaN
# 8          8.0   5           Tola, Tadese   27   M        Addis Ababa   NaN
# 12        12.0  15         April, Lusapho   32   M          Uitenhage   NaN
# 14        14.0  76          Goffi, Danilo   42   M  Parabiago - Milan   NaN
#
#    Country Citizen Unnamed: 9  ... Proj Time Official Time Overall Gender  \
# 0      ETH     NaN        NaN  ...         -       2:09:17       1      1
# 1      ETH     NaN        NaN  ...         -       2:09:48       2      2
# 8      ETH     NaN        NaN  ...         -       2:13:35       9      9
# 12     RSA     NaN        NaN  ...         -       2:16:25      13     13
# 14     ITA     NaN        NaN  ...         -       2:18:44      15     15
#
# ...

# %%
#Print number of rows in original and sampled datafrmae
print(f"\nNumber of rows in original dataframe: {original_row_count}")
print(f"\nNumber of rows in sampled dataframe: {sample_row_count}")
# Out:
# Number of rows in original dataframe: 79638
#
# Number of rows in sampled dataframe: 5331
